# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.
# In the recent study of 249 mice with squamous cell carcinoma (SCC), Capomulin and Ramicane emerged as the most effective treatments based on tumor volume reduction. Capomulin showed the lowest mean and median tumor volumes, indicating superior efficacy compared to other regimens such as Ketapril and Naftisol, which had higher tumor volumes. The study also included a balanced number of male and female mice, which helps ensure the results are reliable. Additionally, the study found that heavier mice tended to have larger tumors when treated with Capomulin.This suggests that mouse weight might affect how well the treatment works. Overall, I think Capomulin could be one of the best treatments for shrinking tumors

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merged_data = pd.merge(study_results,mouse_metadata,on="Mouse ID")

# Display the first 5 rows of the combined data for preview
merged_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
number_mice = merge_data["Mouse ID"].nunique()
number_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
grouped_data = merge_data.groupby(['Mouse ID', 'Timepoint']).size().reset_index(name='count')
duplicate_rows = grouped_data[grouped_data['count'] > 1]
duplicate_mice_ids = duplicate_rows['Mouse ID'].unique()


duplicate_mice_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
fduplicate_mouse_id = 'g989' 
duplicate_mouse_data = merged_data[merged_data['Mouse ID'] == duplicate_mouse_id]

duplicate_mouse_data_sorted = duplicate_mouse_data.sort_values(by='Timepoint').reset_index(drop=True)

duplicate_mouse_data_sorted
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      g989          0           45.000000                 0     Propriva
# 1      g989          0           45.000000                 0     Propriva
# 2      g989          5           48.786801                 0     Propriva
# 3      g989          5           47.570392                 0     Propriva
# 4      g989         10           51.745156                 0     Propriva
# 5      g989         10           49.880528                 0     Propriva
# 6      g989         15           51.325852                 1     Propriva
# 7      g989         15           53.442020                 0     Propriva
# 8      g989         20           55.326122                 1     Propriva
# 9      g989         20           54.657650                 1     Propriva
# 10     g989         25           56.045564                 1     Propriva
# 11     g989         30           59.082294                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = merged_data[merged_data['Mouse ID'] != 'g989']

clean_data = clean_data.drop_duplicates(subset=['Mouse ID', 'Timepoint'])

clean_data_timepoint = clean_data[clean_data['Timepoint'] == 0]

clean_data_timepoint = clean_data_timepoint[['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 
                                             'Metastatic Sites', 'Drug Regimen', 'Sex', 
                                             'Age_months', 'Weight (g)']]

clean_data_timepoint = clean_data_timepoint.reset_index(drop=True)

clean_data_timepoint.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
number_of_mice = clean_data['Mouse ID'].nunique()
number_of_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.

summary_stats = merge_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(
    mean_tumor_volume='mean',
    median_tumor_volume='median',
    tumor_volume_variance='var',
    tumor_volume_std_dev='std',
    tumor_volume_sem=lambda x: st.sem(x))

summary_stats = summary_stats.rename(
    columns={
        'mean_tumor_volume': 'Mean Tumor Volume',
        'median_tumor_volume': 'Median Tumor Volume',
        'tumor_volume_variance': 'Tumor Volume Variance',
        'tumor_volume_std_dev': 'Tumor Volume Std. Dev.',
        'tumor_volume_sem': 'Tumor Volume Std. Err.'
    })

summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
# Using the aggregation method, produce the same summary statistics in a single line

summary_df = summary_stats.reset_index()

summary_df.columns = pd.MultiIndex.from_tuples([
    ( 'Drug Regimen', ''),
    ('Tumor Volume (mm3)', 'mean'),
    ('Tumor Volume (mm3)', 'median'),
    ('Tumor Volume (mm3)', 'var'),
    ('Tumor Volume (mm3)', 'std'),
    ('Tumor Volume (mm3)', 'sem')
])

summary_df.set_index(('Drug Regimen'), inplace=True)


summary_df.head()
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
regimen_counts = merge_data['Drug Regimen'].value_counts()

regimen_counts.plot(kind='bar', color='blue')

plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse timepoints')

# Show the plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
regimen_counts = merge_data['Drug Regimen'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(regimen_counts.index, regimen_counts.values, color='blue')

# Set plot labels and title
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timespoints')

# Show the plot
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender

unique_mice = clean_data.drop_duplicates(subset=['Mouse ID'])

# Double-check gender counts to ensure correct calculation
gender_counts = unique_mice['Sex'].value_counts()

# Calculate the correct percentages manually
total_mice = gender_counts.sum()
gender_percentages = (gender_counts / total_mice) * 100

# Output the gender counts and percentages for validation
print("Gender counts:\n", gender_counts)
print("Gender percentages:\n", gender_percentages)

# Plot the pie chart using the corrected percentages
gender_percentages.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'orange'], labels=gender_counts.index, ylabel='')

# Display the pie chart
plt.show()
# Out:
# Gender counts:
#  Sex
# Male      125
# Female    123
# Name: count, dtype: int64
# Gender percentages:
#  Sex
# Male      50.403226
# Female    49.596774
# Name: count, dtype: float64

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender


# Make the pie chart
unique_mice = clean_data.drop_duplicates(subset='Mouse ID')

# Count the occurrences of each gender
gender_counts = unique_mice['Sex'].value_counts()

# Pie chart data: labels and values
pies = gender_counts.index
pie_votes = gender_counts.values
colors = ["blue", "orange"]  # Color for male and female

# Optional: explode one of the sections for emphasis (if needed)
explode = (0, 0)  # No explode for now, but you can change values if desired

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(pie_votes, explode=explode, labels=pies, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=360)

# Ensure the pie chart is a circle
plt.axis("equal")

# Show the chart
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

filtered_clean_data_timepoint = clean_data_timepoint[clean_data_timepoint['Drug Regimen'].apply(lambda x: x in treatment_regimens)]


final_clean_data_timepoint = filtered_clean_data_timepoint[['Mouse ID', 'Drug Regimen', 'Timepoint', 'Tumor Volume (mm3)']]

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers.
 # Locate the rows which contain mice on each drug and get the tumor volume
    # add subset
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Exclude the duplicate mouse ID
duplicate_mouse_id = 'g989'
filtered_data = merged_data[merged_data['Mouse ID'] != duplicate_mouse_id]

# Remove any potential duplicate rows
clean_data = filtered_data.drop_duplicates(subset=['Mouse ID', 'Timepoint'])

# Get the last (greatest) timepoint for each mouse
last_timepoint = clean_data.groupby('Mouse ID')['Timepoint'].max().reset_index()

# Merge this group df with the cleaned data to get the tumor volume at the last timepoint
final_data = pd.merge(last_timepoint, clean_data, on=['Mouse ID', 'Timepoint'])

# Select only the relevant columns for display
final_tumor_volume = final_data[['Mouse ID', 'Drug Regimen', 'Timepoint', 'Tumor Volume (mm3)']]

# Create an empty list to fill with tumor volume data for plotting
data_to_plot = []

# Loop through each treatment regimen to calculate IQR and identify outliers
for regimen in treatment_regimens:
    # Filter the data for the current regimen
    regimen_data = final_tumor_volume[final_tumor_volume['Drug Regimen'] == regimen]
    
    # Check if there's enough data to calculate quartiles
    if regimen_data.shape[0] > 0:
        # Calculate quartiles and IQR
        quartiles = regimen_data['Tumor Volume (mm3)'].quantile([0.25, 0.75])
        lower_quartile = quartiles[0.25]
        upper_quartile = quartiles[0.75]
        iqr = upper_quartile - lower_quartile

        # Determine the outlier bounds
        lower_bound = lower_quartile - 1.5 * iqr
        upper_bound = upper_quartile + 1.5 * iqr

        # Identify potential outliers
        potential_outliers = regimen_data[(regimen_data['Tumor Volume (mm3)'] < lower_bound) |
                                          (regimen_data['Tumor Volume (mm3)'] > upper_bound)]

        # Print the results for each regimen
        outlier_series = potential_outliers['Tumor Volume (mm3)']
        print(f"{regimen}'s potential outliers: {outlier_series if not outlier_series.empty else 'Series([], Name: Tumor Volume (mm3), dtype: float64)'}")

        # Add the data to the list for plotting
        data_to_plot.append(regimen_data['Tumor Volume (mm3)'])
    else:
        print(f"No data available for {regimen}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
plt.figure(figsize=(10, 6))
plt.boxplot(data_to_plot, labels=treatment_regimens, patch_artist=True)

# Customize plot aesthetics
plt.xlabel('Drug Regimen')
plt.ylabel('Final Tumor Volume (mm3)')

# Display the box plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
merged_data = pd.merge(study_results, mouse_metadata, on="Mouse ID")

# Filter for Capomulin regimen
capomulin_data = merged_data[merged_data['Drug Regimen'] == 'Capomulin']

# Further filter for mouse l509
mouse_l509_data = capomulin_data[capomulin_data['Mouse ID'] == 'l509']

# Sort by timepoint
mouse_l509_data_sorted = mouse_l509_data.sort_values(by='Timepoint').reset_index(drop=True)

# Display the tumor volume data for each timepoint
tumor_volume_over_time = mouse_l509_data_sorted[['Timepoint', 'Tumor Volume (mm3)']]

# Display the data
print(tumor_volume_over_time)
# Out:
#    Timepoint  Tumor Volume (mm3)
# 0          0           45.000000
# 1          5           45.851193
# 2         10           46.759074
# 3         15           47.488599
# 4         20           48.070452
# 5         25           44.006257
# 6         30           44.708055
# 7         35           40.207288
# 8         40           40.770813
# 9         45           41.483008

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_data = merged_data[merged_data['Drug Regimen'] == 'Capomulin']

# Further filter for mouse l509
mouse_l509_data = capomulin_data[capomulin_data['Mouse ID'] == 'l509']

# Sort by timepoint
mouse_l509_data_sorted = mouse_l509_data.sort_values(by='Timepoint').reset_index(drop=True)

# Extract timepoint and tumor volume
timepoints = mouse_l509_data_sorted['Timepoint']
tumor_volumes = mouse_l509_data_sorted['Tumor Volume (mm3)']

# Generate the plot
plt.figure(figsize=(10, 6))
plt.plot(timepoints, tumor_volumes, color='b')
plt.title('Capomulin treatment of mouse l509')
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_data = merged_data[merged_data['Drug Regimen'] == 'Capomulin']

# Calculate the average tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby('Mouse ID').agg({
    'Tumor Volume (mm3)': 'mean',
    'Weight (g)': 'mean'
}).reset_index()

# Generate the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(average_tumor_volume['Weight (g)'], average_tumor_volume['Tumor Volume (mm3)'], color='b')
plt.title('Mouse Weight vs. Average Tumor Volume for Capomulin Regimen')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
capomulin_data = merged_data[merged_data['Drug Regimen'] == 'Capomulin']

# Calculate the average tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby('Mouse ID').agg({
    'Tumor Volume (mm3)': 'mean',
    'Weight (g)': 'mean'
}).reset_index()

# Calculate the correlation coefficient
correlation_coefficient = average_tumor_volume['Weight (g)'].corr(average_tumor_volume['Tumor Volume (mm3)'])
print(f'The correlation between mouse weight and the average tumor volume is {correlation_coefficient:.2f}')

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(
    average_tumor_volume['Weight (g)'], average_tumor_volume['Tumor Volume (mm3)']
)

# Generate the scatter plot with regression line
plt.figure(figsize=(10, 6))
plt.scatter(average_tumor_volume['Weight (g)'], average_tumor_volume['Tumor Volume (mm3)'], color='b')  # Removed the label
plt.plot(
    average_tumor_volume['Weight (g)'], 
    intercept + slope * average_tumor_volume['Weight (g)'], 
    color='r'  # Removed the label
)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
